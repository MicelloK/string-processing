# %% [markdown]
# # Odległość edycyjna

# %% [markdown]
# Zadanie dotyczy wykorzystania odległości edycyjnej.
# 1. Zaimplementuj algorytm obliczania odległości edycyjnej w taki sposób, aby możliwe było określenie przynajmniej jednej sekwencji edycji (dodanie, usunięcie,
# zmiana znaku), która pozwala w minimalnej liczbie kroków, przekształcić jeden łańcuch w drugi.
# 2. Na podstawie poprzedniego punktu zaimplementuj prostą wizualizację działania algorytmu, poprzez wskazanie kolejnych wersji pierwszego łańcucha, w których
# dokonywana jest określona zmiana. "Wizualizacja" może działać w trybie tekstowym. Np. zmiana łańcuch "los” w "kloc” może być zrealizowana następująco:
#     1. \*k\*los (dodanie litery k)
#     2. klo\*c\* (zamiana s->C)
# 3. Przedstaw "nik działania algorytmu z p. 2 dla następujących par łańcuchów:
#     1. los - kloc
#     2. Łódź - Lodz
#     3. kwintesencja - quintessence
#     4. ATGAATCTTACCGCCTCG - ATGAGGCTCTGGCCCCTG
# 4. Zaimplementuj algorytm obliczania najdłuższego wspólnego podciągu dla pary ciągów elementów.
# 5. Korzystając z gotowego tokenizera (np spacy - https://spacy.io/api/tokenizer) dokonaj podziału załączonego tekstu na tokeny.
# 6. Stwórz 2 wersje załączonego tekstu, w których usunięto 3% losowych tokenów.
# 7. Oblicz długość najdłuższego podciągu wspólnych tokenów dla tych tekstów. Traktujemy teraz token (wyraz) jako podstawową, niepodzielną jednostkę ciągu.
# 8. Korzystając z algorytmu z punktu 4 skonstruuj narzędzie, o działaniu podobnym do narzędzia diff, tzn. wskazującego w dwóch plikach linie, które się różnią. Na
# Ujściu narzędzia powinny znaleźć się elementy, które nie należą do najdłuższego wspólnego podciągu. Należy wskazać skąd dana linia pochodzi (< > -
# pierwszy/drugi plik) oraz numer linii w danym pliku. Traktujemy teraz całą linię jako podstawową, niepodzielną jednostkę ciągu.
#
#     **(tutaj zamiast "< >" użyłem "- +")**
#
# 9. Przedstaw wynik działania narzędzia na tekstach z punktu 6. Zwróć uwagę na dodanie znaków przejścia do nowej linii, które są usuwane w trakcie tokenizacji.

# %%
import numpy as np
import colorama
from spacy.lang.pl import Polish
import random

# %%
''' Edit distance between two strings '''

def levenshtein_matrix(str1, str2):
    matrix = np.empty((len(str1)+1, len(str2)+1), dtype=int)
    matrix[0, :] = np.arange(len(str2)+1)
    matrix[:, 0] = np.arange(len(str1)+1)
    for i in range(1, len(str1)+1):
        for j in range(1, len(str2)+1):
            matrix[i, j] = min(matrix[i-1, j]+1, matrix[i, j-1]+1, matrix[i-1, j-1]+(str1[i-1]!=str2[j-1]))
    return matrix

def levenshtein_distance(str1, str2):
    return levenshtein_matrix(str1, str2)[-1, -1]

def levenshtein_bactrace(str1, str2, trace_print=True):
    if trace_print:
        print(">> TRACEBACK <<")
        print("Input string:", str1)
        print("Output string:", str2)
        print("--------------------")

    matrix = levenshtein_matrix(str1, str2)
    i, j = len(str1), len(str2)
    trace = [(i, j, "end")]
    while i > 0 and j > 0:
        action = True
        if matrix[i, j] == matrix[i-1, j-1] + 1: # replace
            trace.append((i-1, j-1, "r"))
            input_str = str1[:i-1] + colorama.Fore.CYAN + str1[i-1] + colorama.Fore.RESET + str1[i:]
            output_str = str1[:i-1] + str2[j-1] + str1[i:]
            i, j = i-1, j-1
        elif matrix[i, j] == matrix[i-1, j] + 1: # delete
            trace.append((i-1, j, "d"))
            input_str = str1[:i-1] + colorama.Fore.RED + str1[i-1] + colorama.Fore.RESET + str1[i:]
            output_str = str1[:i-1] + str1[i:]
            i -= 1
        elif matrix[i, j] == matrix[i, j-1] + 1: # insert
            trace.append((i, j-1, "i"))
            input_str = str1[:i] + colorama.Fore.GREEN + str2[j-1] + colorama.Fore.RESET + str1[i:]
            output_str = str1[:i] + str2[j-1] + str1[i:]
            j -= 1
        else: # match
            action = False
            trace.append((i-1, j-1, "m"))
            input_str = output_str = str1
            i, j = i-1, j-1

        if trace_print and action:
            print(input_str, output_str, sep=" -> ")
        str1 = output_str

    while i > 0:
        trace.append((i-1, j, "d"))
        if trace_print:
            input_str = str1[:i-1] + colorama.Fore.RED + str1[i-1] + colorama.Fore.RESET + str1[i:]
            output_str = str1[:i-1] + str1[i:]
            print(input_str, output_str, sep=" -> ")
        str1 = output_str
        i -= 1

    while j > 0:
        trace.append((i, j-1, "i"))
        if trace_print:
            input_str = str1[:i] + colorama.Fore.GREEN + str2[j-1] + colorama.Fore.RESET + str1[i:]
            output_str = str1[:i] + str2[j-1] + str1[i:]
            print(input_str, output_str, sep=" -> ")
        str1 = output_str
        j -= 1
    
    if trace_print:
        
        print("--------------------")

    return trace

# %%
levenshtein_bactrace("los", "kloc");
# Out:
# >> TRACEBACK <<
# Input string: los
# Output string: kloc
# --------------------
# los -> loc
# kloc -> kloc
# --------------------

# %%
levenshtein_bactrace("Łódź", "Lodz");
# Out:
# >> TRACEBACK <<
# Input string: Łódź
# Output string: Lodz
# --------------------
# Łódź -> Łódz
# Łódz -> Łodz
# Łodz -> Lodz
# --------------------

# %%
levenshtein_bactrace("kwintesencja", "quintessence");
# Out:
# >> TRACEBACK <<
# Input string: kwintesencja
# Output string: quintessence
# --------------------
# kwintesencja -> kwintesencje
# kwintesencje -> kwintesence
# kwintessence -> kwintessence
# kwintessence -> kuintessence
# kuintessence -> quintessence
# --------------------

# %%
levenshtein_bactrace("ATGAATCTTACCGCCTCG", "ATGAGGCTCTGGCCCCTG");
# Out:
# >> TRACEBACK <<
# Input string: ATGAATCTTACCGCCTCG
# Output string: ATGAGGCTCTGGCCCCTG
# --------------------
# ATGAATCTTACCGCCTCG -> ATGAATCTTACCGCCTG
# ATGAATCTTACCGCCTG -> ATGAATCTTACCCCCTG
# ATGAATCTTACCCCCTG -> ATGAATCTTAGCCCCTG
# ATGAATCTTAGCCCCTG -> ATGAATCTTGGCCCCTG
# ATGAATCTCTGGCCCCTG -> ATGAATCTCTGGCCCCTG
# ATGAATCTCTGGCCCCTG -> ATGAAGCTCTGGCCCCTG
# ATGAAGCTCTGGCCCCTG -> ATGAGGCTCTGGCCCCTG
# --------------------

# %%
''' Longest common subsequence '''

def lcs_matrix(str1, str2):
    matrix = np.empty((len(str1)+1, len(str2)+1), dtype=int)
    matrix[0, :] = np.zeros(len(str2)+1)
    matrix[:, 0] = np.zeros(len(str1)+1)
    for i in range(1, len(str1)+1):
        for j in range(1, len(str2)+1):
            if str1[i-1] == str2[j-1]:
                matrix[i, j] = matrix[i-1, j-1] + 1
            else:
                matrix[i, j] = max(matrix[i-1, j], matrix[i, j-1])
    return matrix

def lcs(str1, str2):
    matrix = lcs_matrix(str1, str2)
    i, j = len(str1), len(str2)
    lcs = []
    while i > 0 and j > 0:
        if str1[i-1] == str2[j-1]:
            lcs.append(str1[i-1])
            i, j = i-1, j-1
        elif matrix[i-1, j] > matrix[i, j-1]:
            i -= 1
        else:
            j -= 1

    while i > 0:
        lcs.append(str1[i-1])
        i -= 1

    while j > 0:
        lcs.append(str2[j-1])
        j -= 1

    return ''.join(reversed(lcs))

# %%
''' Tokenizer '''

nlp = Polish()
def tokenize(text):
    return [token.text for token in nlp.tokenizer(text)]

# %%
''' LCS on tokens '''

f = open("romeo-i-julia-700.txt", "r", encoding="utf-8")
text = f.read()
f.close()

tokens = tokenize(text)

def delete_random_tokens(tokens, n):
    for _ in range(n):
        tokens.pop(random.randint(0, len(tokens)-1))
    return tokens

n = round(len(tokens) * 0.03)
tokens1 = delete_random_tokens(tokens.copy(), n)
tokens2 = delete_random_tokens(tokens.copy(), n)

with open("output1.txt", "w", encoding="utf-8") as f1, open("output2.txt", "w", encoding="utf-8") as f2:
    f1.write(' '.join(tokens1))
    f2.write(' '.join(tokens2))

# %%
print("LCS length:", len(lcs(tokens1, tokens2)))
# Out:
# LCS length: 10450

# %%
''' diff '''

def compare_files(file1, file2):
    with open(file1, 'r', encoding='utf-8') as f1, open(file2, 'r', encoding='utf-8') as f2:
        lines1 = f1.readlines()
        lines2 = f2.readlines()

        lcs_lines = lcs(lines1, lines2)

        f1_count = len([line for line in lines1 if line not in lcs_lines])
        f2_count = len([line for line in lines2 if line not in lcs_lines])

        print(">> FILE DIFFERENCES <<")
        print("---", file1)
        print("+++", file2)
        print(f"@@ -{f1_count} | +{f2_count} @@")
        print("----------------------\n")
        
        i, j = 0, 0
        while i < len(lines1) and j < len(lines2):
            if lines1[i] in lcs_lines:
                i += 1
            elif lines2[j] in lcs_lines:
                j += 1
            else:
                if i < j:
                    print("-", i+1, colorama.Fore.RED + lines1[i] + colorama.Fore.RESET, end="")
                    i += 1
                else:
                    print("+", j+1, colorama.Fore.GREEN + lines2[j] + colorama.Fore.RESET, end="")
                    j += 1

# %%
compare_files("output1.txt", "output2.txt")
# Out:
# >> FILE DIFFERENCES <<
# --- output1.txt
# +++ output2.txt
# @@ -123 | +127 @@
# ----------------------
#
# + 16   * MERKUCJO — krewny księcia * BENWOLIO — synowiec Montekiego
# - 16   * MERKUCJO — krewny księcia
# - 17   * BENWOLIO — synowiec Montekiego
# + 30   * JULIA — córka Kapuletów
# + 31   MARTA — mamka Julii
# - 31   JULIA — córka Kapuletów
# + 32   * Obywatele , różne osoby płci obojej , liczący się do przyjaciół obu domów , maski , straż wojskowa i inne osoby .
# - 32   * MARTA — mamka Julii
# - 33   * Obywatele weroneńscy , różne osoby płci obojej , liczący się do przyjaciół obu domów , maski , straż wojskowa i inne osoby .
# + 45  Dwa , zacne jednako i sławne —
# + 46  Tam , gdzie się rzecz ta rozgrywa , w Weronie ,
# - 46  Dwa rody , zacne jednako i sławne —
# + 47  Do nowej zbrodni pchają złości dawne ,
# - 47  Tam , gdzie się rzecz ta , w Weronie , Do nowej zbrodni pchają złości dawne ,
# + 50  Z łon tych dwu wzięło bowiem życie ,
# - 50  Z łon tych dwu wrogów wzięło bowiem życie ,
# + 52  Po pełnym przygód nieszczęśliwych
# - 52  Po pełnym przygód nieszczęśliwych bycie
# + 53  Śmierć ich stłumiła rodzicielskie boje .
# - 53  Śmierć ich stłumiła rodzicielskie .
# + 57  Aż ją zakończy dzieci zgon przedwczesny ,
# - 57  Aż ją zakończy dzieci zgon przedwczesny , Dwugodzinnego treścią ,
# + 58  Dwugodzinnego treścią przedstawienia ,
# - 59  Które cierpliwymi względy ,
# + 60  Które otoczcie cierpliwymi względy ,
# - 60  Jest w nim co my usuniem błędy …
# + 61  Jest w nim co złego my usuniem błędy …
# - 71  / Plac publiczny . Wchodzą Samson i Grzegorz uzbrojeni w tarcze i miecze . /
# + 72  / Plac publiczny . Samson i Grzegorz uzbrojeni w tarcze i miecze /
# - 76  Dalipan , Grzegorzu , nie będziem darli pierza
# + 77  Dalipan , , nie będziem darli pierza .
# - 86  Ale będziemy darli koty jak z nami zadrą .
# + 87  Ale będziemy darli koty , jak z nami zadrą .
# - 91  Kto zechce zadrzeć z nami , będzie musiał zadrżeć .
# + 92  Kto zechce z nami będzie musiał zadrżeć .
# - 101  Tak , ale nie zaraz zwykłeś się dać rozruchać . SAMSON
# + 102  Tak , ale nie zaraz zwykłeś się dać rozruchać .
# - 103  Te psy z domu Montekich rozruchać mię bardzo łatwo .
# + 107  Te psy z domu Montekich rozruchać mię mogą bardzo łatwo .
# - 123  Prawda , dlatego to kobiety , jako najsłabsze , tulą się zawsze do muru . Ja też odtrącę od muru ludzi Montekich , a kobiety Montekich przyprę do muru .
# + 127  Prawda , dlatego to kobiety , jako najsłabsze , się zawsze do . Ja też odtrącę od muru ludzi Montekich , a kobiety Montekich przyprę do muru .
# - 133  Mniejsza mi o to , będę nieubłagany . Pobiwszy ludzi , wywrę wściekłość na kobietach : rzeź między nimi sprawię .
# + 137  Mniejsza mi o to będę nieubłagany . Pobiwszy ludzi , wywrę wściekłość na kobietach rzeź między nimi sprawię .
# - 143  inaczej : wtłoczę w każdą po kolei . Wiadomo , że się do lwów liczę .
# + 147  Nie inaczej : wtłoczę miecz w każdą po kolei . Wiadomo , że do lwów liczę .
# - 148  Tym , że się liczysz do zwierząt bo gdybyś się liczył do ryb , to byłbyś pewnie sztokfiszem . Weź no się za instrument , bo oto nadchodzi dwóch domowników Montekiego .
# + 152  Tym lepiej , że się liczysz do zwierząt ; bo gdybyś się liczył do ryb , to byłbyś pewnie sztokfiszem . Weź no się za instrument bo oto nadchodzi domowników Montekiego .
# - 170  Ja bym się bać z twojej przyczyny !
# + 174  Ja bym się miał bać z twojej przyczyny !
# - 175  Miejmy prawo za sobą , niech oni zaczną
# + 177  SAMSON Miejmy prawo za sobą , niech oni zaczną .
# - 180  Marsa im nastawię przechodząc ; niech go sobie , jak chcą , tłumaczą . SAMSON
# + 182  Marsa im nastawię przechodząc ; niech go sobie , jak chcą , tłumaczą .
# - 182  Nie jak chcą , ale jak śmią . Ja im gębę wykrzywię ; hańba im , jeśli to ścierpią .
# + 187  Nie jak chcą , ale jak śmią . Ja im gębę wykrzywię ; hańba im , to ścierpią .
# - 187  Skrzywiłeś się na nas , mości panie ?
# + 192  Skrzywiłeś się na nas , mości panie ? SAMSON
# - 204  – ż mieli prawo za sobą , jak powiem : tak jest ?
# + 206  Będziemy – ż mieli prawo za , jak powiem : tak jest ?
# - 209  Nie
# + 211  Nie .
# - 243  / Benwolio ukazuje się w głębi . /
# + 245  / Benwolio ukazuje w głębi . /
# - 248  / na stronie do Samsona
# + 250  / na stronie do Samsona /
# - 265  Dobądźcie mieczów , jeśli macie serca . Grzegorzu , pamiętaj o swoim pchnięciu .
# + 267  Dobądźcie mieczów , jeśli macie serca . Grzegorzu , o swoim pchnięciu .
# - 272  / Rozdziela swoim mieczem . /
# + 274  / Rozdziela ich swoim mieczem . /
# - 279  Cóż to ? krzyżujesz oręż z parobkami ? Do mnie , Benwolio ! pilnuj swego życia .
# + 281  Cóż to ? krzyżujesz oręż z parobkami ?
# + 282  Do mnie , Benwolio ! pilnuj swego życia .
# - 285  Albo wraz ze mną rozdziel nim tych ludzi .
# + 288  Albo wraz mną rozdziel nim tych ludzi .
# - 291  Tego wyrazu , tak jak nienawidzę
# - 292  Szatana , wszystkich Montekich i ciebie .
# + 294  Tego wyrazu , tak jak nienawidzę Szatana , wszystkich Montekich i ciebie .
# - 295  / . Nadchodzi kilku przyjaciół obu partii i mieszają się do zwady ; wkrótce potem wchodzą mieszczanie z pałkami . /
# + 297  / Walczą . Nadchodzi kilku przyjaciół obu partii i mieszają się do zwady ; wkrótce potem wchodzą mieszczanie z pałkami . /
# - 319  Miecz , ! Stary Monteki nadchodzi .
# + 321  Miecz , mówię ! Stary Monteki nadchodzi .
# - 322  / Wchodzą Monteki i Pani Monteki . /
# + 324  / Wchodzą Monteki i Pani Monteki /
# - 327  Ha ! nędzny Kapulecie !
# + 329  Ha ! nędzny Kapulecie
# - 336  Nie puszczę cię na krok , gdy wróg przed .
# + 338  Nie puszczę cię na krok , gdy wróg przed tobą .
# - 346  Co wściekłych swoich gniewów żar gasicie
# + 348  Co wściekłych swoich gniewów żar
# - 349  Z dłoni skrwawionych tę buntowniczą
# + 351  Z dłoni skrwawionych tę broń buntowniczą
# - 351  Wasz rozjątrzony książę .
# + 353  Wasz rozjątrzony książę postanawia .
# - 353  Przez was , Monteki oraz Kapulecie ,
# - 354  Trzykroć już spokój miasta ,
# + 355  Przez was , ,
# + 356  Trzykroć już spokój miasta zakłóciły ,
# - 357  Porzucić swoje wygodne
# - 358  I w stare dłonie stare ująć miecze ,
# + 359  Porzucić swoje wygodne przybory
# + 360  I stare dłonie stare ująć miecze ,
# - 362  Zamęt opłacicie życiem .
# + 364  Zamęt pokoju opłacicie życiem .
# - 364  Ty , Kapulecie , pójdziesz ze mną razem ;
# - 365  Ty zaś , Monteki , po południu
# + 366  Ty , Kapulecie , pójdziesz ze mną razem
# - 366  Na ratusz , gdzie ci dokładnie w tym względzie
# + 367  Ty zaś , Monteki przyjdziesz po południu
# - 367  Dalsza ma wola oznajmiona będzie .
# + 368  Na ratusz , gdzie ci dokładnie w tym
# - 368  Jeszcze raz wzywam wszystkich obecnych
# + 369  ma wola oznajmiona będzie .
# + 370  Jeszcze raz wzywam wszystkich tu
# - 371  / Książę z orszakiem wychodzi . Podobnież Kapulet , Pani Kapulet , Tybalt , obywatele i słudzy . /
# + 373  / Książę z orszakiem . Podobnież Kapulet , Pani Kapulet , Tybalt , obywatele i słudzy . /
# - 376  Kto wszczął tę nową zwadę ? Mów , synowcze ,
# - 377  Był żeś tu , gdy się to zaczęło ?
# + 378  Kto wszczął tę nową zwadę Mów , synowcze ,
# + 379  Był żeś tu wtedy , gdy się to zaczęło ?
# - 382  Nieprzyjaciela naszego pachołcy
# - 383  I wasi już się bili , kiedym nadszedł ;
# + 384  Nieprzyjaciela naszego pachołcy I wasi już się bili , kiedym nadszedł ;
# - 384  Dobyłem broni , aby ich :
# + 385  Dobyłem broni , aby ich rozdzielić :
# - 385  Wtem wpadł szalony Tybalt z gołym mieczem
# + 386  Wtem wpadł szalony Tybalt z gołym mieczem ,
# - 387  Jął się wywijać nim i siec powietrze ,
# + 388  Jął się wywijać nim i siec powietrze , Które świszczało tylko szydząc z marnych
# - 388  Które świszczało tylko szydząc z marnych
# + 389  Jego zamachów . Gdyśmy tak ze
# - 389  Jego zamachów . Gdyśmy tak ze sobą
# + 390  Cięcia i pchnięcia , zbiegł się
# - 390  Cięcia i pchnięcia zamieniali , zbiegł się
# + 392  Aż książę nadszedł i wszystkich .
# - 392  Aż książę nadszedł i rozdzielił wszystkich .
# + 397  Lecz gdzież Romeo ? Widział żeś go dzisiaj ?
# - 397  Lecz Romeo ? Widział żeś go dzisiaj ?
# + 403  Godziną pierwej , wspaniałe słońce
# - 403  Godziną pierwej , nim wspaniałe słońce
# + 406  W sykomorowy ów gaj , co się
# - 406  W sykomorowy ów gaj , co się ciągnie
# + 407  Ku południowi naszego miasta .
# - 407  Ku południowi od naszego miasta .
# + 408  Tam , już tak rano , syn wasz się przechadzał .
# - 408  Tam , już tak rano , wasz się przechadzał .
# + 409  Ledwiem go ujrzał , pobiegłem ku niemu ;
# - 409  Ledwiem go ujrzał , pobiegłem niemu ;
# + 410  Lecz on , spostrzegłszy mię skrył się natychmiast
# - 410  Lecz on , spostrzegłszy mię , skrył się natychmiast
# + 411  I w najciemniejszej ukrył się gęstwinie .
# - 411  I w najciemniejszej ukrył gęstwinie .
# + 417  Stroniąc od tego co rad mnie unikał .
# - 417  Stroniąc od tego , co rad mnie unikał .
# + 432  W czarne bezdroża dusza zajdzie ,
# - 432  W czarne bezdroża dusza jego zajdzie ,
# + 438  Szanowny stryju , znasz – że powód tego ?
# - 438  stryju znasz – że powód tego ?
# + 443  Nie znam i niego wydobyć nie mogę .
# - 443  Nie znam i z niego wydobyć nie mogę .
# + 454  Lecz on jedyny powiernik swych smutków .
# - 454  Lecz on jedyny swych smutków .
# + 455  Tak im jest wierny tak zamknięty w sobie ,
# - 455  Tak im jest wierny , tak zamknięty sobie ,
# + 456  Od wszelkiej tak daleki
# - 456  Od otwartości wszelkiej tak daleki
# + 458  Nim światu wonny swój kielich roztoczył
# - 458  Nim światu swój kielich roztoczył
# + 460  Gdybyśmy mogli dojść tych trosk zarodka ,
# - 460  Gdybyśmy mogli dojść tych zarodka ,
# + 461  Nie zbrakłoby nam zaradczego środka .
# - 461  Nie zbrakłoby nam zaradczego środka . / Romeo ukazuje się w głębi . /
# + 463  / Romeo ukazuje się w głębi . /
# - 472  Obyś w tej sprawie , co serce rani ,
# - 473  być szczęśliwszym od nas ! Pójdźmy , pani .
# + 474  Obyś w tej sprawie , co nam serce rani ,
# + 475  Mógł być szczęśliwszym od nas ! Pójdźmy , pani .
# - 475  / Wychodzą i Pani Monteki . /
# + 477  / Wychodzą Monteki i Pani . /
# - 480  dobry , bracie .
# + 482  Dzień dobry , bracie .
# - 522                          Jak to ? brak miłości ?
# + 524                          Jak to ? brak ?
# - 527  Brak jej tam , skąd pragnął wzajemności .
# + 529  Brak jej tam , skąd bym pragnął wzajemności . BENWOLIO
# + 532  Miłość jest w gruncie tak srogą tyranką ? ROMEO
# - 533  Miłość jest w gruncie tak srogą tyranką ?
# + 536  Gdzież dziś jeść będziem ? Ach ! Był tu podobno
# + 538  W grze tu nienawiść wielka , i miłość .
# + 539  O ! wy sprzeczności niepojęte dziwa !
# - 540  Gdzież dziś jeść będziem ? Ach tu podobno
# + 541  Coś narodzone z niczego ! Pieszczoto
# + 542  Odpychająca ! pustoto !
# - 542  W tu nienawiść wielka , lecz i miłość . O ! wy sprzeczności niepojęte dziwa !
# + 543  Szpetny wdzięków ! Ciężki puchu !
# - 544  Coś narodzone z niczego !
# - 545  Odpychająca ! Poważna pustoto !
# + 546  Taką niełączność łączy moja miłość .
# - 546  Szpetny chaosie wdzięków ! Ciężki puchu !
# + 547  Czy się nie śmiejesz ? BENWOLIO
# - 549  Taką łączy moja miłość .
# - 550  Czy się nie śmiejesz ?
# + 570  Nie ulgą ale nowym jest kamieniem
# + 575  Czymże jest więcej Istnym amalgamem ,
# - 576  Nie ulgą , ale nowym jest kamieniem
# + 579  / chce /
# - 581  Czymże jest więcej ? Istnym amalgamem ,
# + 584                          Zaczekaj ! krzywdę mi sprawił ,
# + 585  Gdybyś mą przyjaźń z kwitkiem tak zostawił .
# - 585  / chce odejść /
# - 590                          Zaczekaj ! krzywdę byś mi ,
# - 591  Gdybyś mą z kwitkiem tak zostawił .
# + 607                          Nie jęczyć ,
# + 608  Tylko mi klucz dać do tego problemu ,
# + 609  Kogóż to kochasz ? Powiedz
# - 613                          Nie jęczyć
# - 614  Tylko mi klucz dać do tego problemu
# - 615  Kogóż to kochasz ? Powiedz .
# + 616  Dobre dla tego , kto jest w tak złym stanie ?
# - 622  Dobre tego , kto jest w tak złym stanie ?
# + 623  Gdym to pomyślał , nimeś mi powierzył .
# + 628  Biegle celujesz . I ta którą ,
# - 629  Gdym to pomyślał , nimeś powierzył .
# + 634                          W piękny cel trafić najłatwiej .
# - 634  Biegle celujesz . I ta , którą kocham ,
# + 639  A właśnieś chybił . tu kołczany
# - 640                          W piękny cel najłatwiej
# + 641  twardą zbroją wstydliwości swojej
# + 642  Grotów miłości wcale się nie boi ;
# - 645  A właśnieś chybił . Niczym tu kołczany
# - 647  Pod twardą zbroją wstydliwości swojej
# - 648  Grotów miłości wcale się nie boi
# + 653  Wiecznie – ż chce sama zostać z swym bogactwem ?
# + 658  Tak jest ; i skąpstwo to jest marnotrawstwem ,
# + 659  Bo piękność , którą własna srogość strawia ,
# - 659  Wiecznie ż chce sama zostać z swym bogactwem ?
# + 662  Zbyt mądrze piękna : stąd istnym jest głazem .
# + 663  Przysięgła nigdy nie kochać i dzięki
# + 664  Temu skazanym - wieczne cierpieć męki .
# - 664  Tak jest ; i to jest marnotrawstwem ,
# - 665  Bo piękność którą własna srogość ,
# - 668  Zbyt mądrze piękna : stąd istnym jest głazem . Przysięgła nigdy nie kochać i dzięki Temu skazanym - wieczne cierpieć męki .
# + 669  Jest na to : przestań myśleć o niej .
# - 673  Jest na to rada : przestań myśleć o niej .
# + 674  Doradź że także , jakim bym sposobem
# + 675  Mógł przestać myśleć .
# - 676  ROMEO Doradź – że także , jakim bym sposobem Mógł przestać myśleć .
# + 678  BENWOLIO Dając oczom wolność
# + 679  Rozpatrywania się w pięknościach .
